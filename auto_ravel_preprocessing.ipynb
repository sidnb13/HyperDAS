# %%
from datasets import load_from_disk, Dataset
from torch.utils.data import DataLoader
import torch
from tqdm import tqdm

# %%
def get_model_prediction_labels(model, tokenizer, target_dataset, max_num_tokens=3):
    tokenizer.padding_side = "left"
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id

    def collate_fn(batch):
        input_texts = []

        for b in batch:
            prefix = b["context"]
            suffix = b["prompt"]

            input_text = f"{tokenizer.bos_token} {prefix}{suffix}"
            input_texts.append(input_text)

        inputs = tokenizer(
            input_texts, return_tensors="pt", padding=True, truncation=True
        )
        # inputs["position_ids"] = torch.cumsum(inputs["attention_mask"], dim=1) * inputs["attention_mask"] - 1

        return inputs

    model_predictions = []

    dataloader = DataLoader(
        target_dataset, batch_size=16, collate_fn=collate_fn, shuffle=False
    )

    model = model.to("cuda")
    for batch in tqdm(dataloader):
        batch = {k: v.to("cuda") for k, v in batch.items()}
        outputs = model.generate(**batch, max_new_tokens=max_num_tokens)

        outputs = outputs[:, batch["input_ids"].shape[1] :]

        predictions = [
            tokenizer.decode(output, skip_special_tokens=True) for output in outputs
        ]
        model_predictions.extend(predictions)

    target_dataset = target_dataset.add_column("model_predictions", model_predictions)

    return target_dataset

# %%
from transformers import AutoTokenizer, LlamaForCausalLM

model = LlamaForCausalLM.from_pretrained(
    "/nlp/scr/sjd24/llama3-8b", torch_dtype=torch.bfloat16
)
tokenizer = AutoTokenizer.from_pretrained("/nlp/scr/sjd24/llama3-8b")
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [04:10<00:00, 62.52s/it]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = model.to("cuda")

# %%
import random


def process_autoravel_dataset(
    model, tokenizer, target_dataset, max_num_tokens=3, source_per_target=1, domain=None
):
    tokenizer.padding_side = "left"
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id

    processed_dataset = []

    all_entities = set(d["entity"] for d in target_dataset)

    def collate_fn(batch):
        input_texts = []

        for b in batch:
            input_text = tokenizer.bos_token + " " + b["input_prompt"]
            input_texts.append(input_text)

        inputs = tokenizer(
            input_texts, return_tensors="pt", padding=True, truncation=True
        )
        # inputs["position_ids"] = torch.cumsum(inputs["attention_mask"], dim=1) * inputs["attention_mask"] - 1

        return inputs

    for entity in tqdm(all_entities):
        entity_data = target_dataset.filter(lambda x: x["entity"] == entity)

        all_contexts = set(d["context"] for d in entity_data)

        for i, context in enumerate(all_contexts):
            context_data = entity_data.filter(lambda x: x["context"] == context)
            attributes = set([d["attribute"] for d in context_data])

            # Remove data entry with duplicate attributes
            for attribute in attributes:
                attribute_data = context_data.filter(
                    lambda x: x["attribute"] == attribute
                )
                if len(attribute_data) > 1:
                    context_data = context_data.filter(
                        lambda x: x["attribute"] != attribute
                    )

                    context_data = context_data.add_item(random.choice(attribute_data))

            for _ in range(source_per_target):
                source_entity = random.choice(list(all_entities - {entity}))
                source_entity_data = target_dataset.filter(
                    lambda x: x["entity"] == source_entity
                )
                source_all_contexts = set(d["context"] for d in source_entity_data)

                source_context = random.choice(list(source_all_contexts))

                labels_dict = {"base": dict(), "source": dict()}

                label_dataset = []
                for attribute in attributes:
                    base_attribute_data = context_data.filter(
                        lambda x: x["attribute"] == attribute
                    )
                    assert (
                        len(base_attribute_data) == 1
                    ), f"Attribute {attribute} has {len(base_attribute_data)} entries in the dataset"
                    base_attribute_data = base_attribute_data[0]

                    input_prompt = (
                        base_attribute_data["context"] + base_attribute_data["prompt"]
                    )
                    counterfactual_input_prompt = (
                        source_context + base_attribute_data["prompt"]
                    )

                    label_dataset.append(
                        {
                            "input_prompt": input_prompt,
                            "attribute": attribute,
                            "entity_type": "base",
                        }
                    )
                    label_dataset.append(
                        {
                            "input_prompt": counterfactual_input_prompt,
                            "attribute": attribute,
                            "entity_type": "source",
                        }
                    )

                label_dataset = Dataset.from_list(label_dataset)
                model_predictions = []

                label_dataloader = DataLoader(
                    label_dataset, batch_size=4, collate_fn=collate_fn, shuffle=False
                )
                for batch in tqdm(label_dataloader):
                    batch = {k: v.to(model.device) for k, v in batch.items()}
                    outputs = model.generate(**batch, max_new_tokens=max_num_tokens)
                    outputs = outputs[:, batch["input_ids"].shape[1] :]
                    predictions = [
                        tokenizer.decode(output, skip_special_tokens=True)
                        for output in outputs
                    ]
                    model_predictions.extend(predictions)

                for label, data in zip(model_predictions, label_dataset):
                    labels_dict[data["entity_type"]][data["attribute"]] = label

                for attribute in attributes:
                    base_attribute_data = context_data.filter(
                        lambda x: x["attribute"] == attribute
                    )
                    assert (
                        len(base_attribute_data) == 1
                    ), f"Attribute {attribute} has {len(base_attribute_data)} entries in the dataset"
                    base_attribute_data = base_attribute_data[0]

                    input_prefix = base_attribute_data["context"]
                    input_suffix = base_attribute_data["prompt"]
                    counterfactual_input_prefix = source_context
                    counterfactual_input_suffix = base_attribute_data["prompt"]
                    edit_instruction = attribute.title()
                    entity = entity
                    counterfactual_entity = source_entity
                    attribute_type = "cause"
                    domain = "unknown" if domain is None else domain
                    attribute = attribute
                    target = labels_dict["base"][attribute]
                    counterfactual_target = labels_dict["source"][attribute]

                    processed_dataset.append(
                        {
                            "input_prefix": input_prefix,
                            "input_suffix": input_suffix,
                            "counterfactual_input_prefix": counterfactual_input_prefix,
                            "counterfactual_input_suffix": counterfactual_input_suffix,
                            "edit_instruction": edit_instruction,
                            "entity": entity,
                            "counterfactual_entity": counterfactual_entity,
                            "target": target,
                            "counterfactual_target": counterfactual_target,
                            "attribute_type": attribute_type,
                            "domain": domain,
                            "attribute": attribute,
                        }
                    )

                    all_other_attributes = attributes - {attribute}

                    for other_attribute in all_other_attributes:
                        other_attribute_base_data = context_data.filter(
                            lambda x: x["attribute"] == other_attribute
                        )
                        assert (
                            len(other_attribute_base_data) == 1
                        ), f"Attribute {other_attribute} has {len(other_attribute_base_data)} entries in the dataset"
                        other_attribute_base_data = other_attribute_base_data[0]

                        other_target = labels_dict["base"][other_attribute]
                        other_counterfactual_target = labels_dict["source"][
                            other_attribute
                        ]

                        processed_dataset.append(
                            {
                                "input_prefix": input_prefix,
                                "input_suffix": other_attribute_base_data["prompt"],
                                "counterfactual_input_prefix": counterfactual_input_prefix,
                                "counterfactual_input_suffix": other_attribute_base_data[
                                    "prompt"
                                ],
                                "edit_instruction": edit_instruction,
                                "entity": entity,
                                "counterfactual_entity": counterfactual_entity,
                                "target": other_target,
                                "counterfactual_target": other_counterfactual_target,
                                "attribute_type": "isolate",
                                "domain": domain,
                                "attribute": other_attribute,
                            }
                        )

    return Dataset.from_list(processed_dataset)


human_dataset = load_from_disk("auto_ravel/Q5")
processed_dataset = process_autoravel_dataset(model, tokenizer, human_dataset)
# Out:
#   0%|          | 0/522 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00,  9.86it/s]
#   0%|          | 1/522 [00:01<09:31,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.10it/s]
#   0%|          | 2/522 [00:01<05:59,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.11it/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 996.86 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1219.98 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1077.22 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 998.35 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1182.83 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1041.06 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1155.85 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1101.81 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 16.90it/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1088.05 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1125.08 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1098.13 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1057.73 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1168.82 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1100.65 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1115.88 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1178.67 examples/s]
#   1%|          | 4/522 [00:02<04:47,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 16.85it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 207940.37 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 13.87it/s]
#   1%|          | 6/522 [00:03<03:31,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00,  9.94it/s]
#   1%|▏         | 7/522 [00:03<03:32,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.13it/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 1903.85 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2070.72 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1819.70 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2009.91 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1971.18 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 1561.97 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 1632.41 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 1692.75 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1724.68 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1511.89 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1527.25 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1839.11 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1934.71 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1701.07 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1716.43 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1892.67 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1896.29 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 2038.12 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1910.24 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1697.73 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1854.56 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1940.63 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1764.14 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00,  9.87it/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1415.41 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1500.11 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1485.28 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1872.26 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1765.57 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1921.42 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1793.56 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1851.10 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1848.90 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1948.82 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1771.13 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1581.88 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1766.19 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1840.88 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2024.07 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1809.87 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1581.01 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1673.91 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1532.75 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1557.27 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1331.14 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1396.19 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1489.45 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1232.46 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1403.34 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1316.19 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1490.46 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1312.61 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1438.77 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1377.44 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00,  9.80it/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 996.70 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1139.85 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1192.92 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1419.06 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1329.25 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1434.54 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1367.56 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1466.49 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1406.49 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1343.60 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 148279.84 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 11.53it/s]
#   2%|▏         | 11/522 [00:06<05:58,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.13it/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1303.52 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1221.37 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1238.35 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1219.12 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1220.93 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 219315.15 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1380.97 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 13.17it/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 994.70 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1061.79 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1080.51 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1231.29 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1356.84 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1365.14 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1331.15 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1343.80 examples/s]
# Filter: 100%|██████████| 9/9 [00:00<00:00, 1264.78 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1831.33 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1878.52 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1841.41 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1831.57 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1940.01 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1873.16 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1922.84 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1851.16 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1952.38 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1889.33 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 2027.21 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1980.03 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1858.23 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 16.98it/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 2015.45 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1862.10 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1866.11 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1530.64 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1910.58 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1960.38 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1774.82 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1660.00 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1593.21 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1783.29 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1643.09 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1679.58 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1727.86 examples/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 2417.00 examples/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 2422.51 examples/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 2624.36 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2554.20 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2405.88 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2335.93 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2337.72 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2148.49 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1997.02 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2182.91 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1793.68 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1875.55 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1685.59 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1754.33 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1816.50 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1854.86 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1758.07 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1693.53 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1875.25 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1756.59 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1749.51 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1761.76 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1760.22 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1790.46 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 16.68it/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1661.82 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1808.73 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1648.87 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1455.60 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1650.22 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1761.88 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1630.17 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1418.47 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1678.23 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1644.23 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1830.11 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1796.08 examples/s]
#   3%|▎         | 15/522 [00:09<06:51,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 12.03it/s]
#   3%|▎         | 16/522 [00:10<06:32,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00,  9.93it/s]
#   3%|▎         | 17/522 [00:11<06:27,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.26it/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 799.68 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 219955.05 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 806.60 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 810.86 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 787.91 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 837.52 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 868.30 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 11.48it/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 674.33 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 659.29 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 689.55 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 896.28 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 913.46 examples/s]
# Filter: 100%|██████████| 6/6 [00:00<00:00, 889.98 examples/s]
#   4%|▎         | 19/522 [00:11<04:56,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.11it/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 1935.53 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 1960.22 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1724.32 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1790.14 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2215.98 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2204.05 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2045.25 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 1985.50 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2035.21 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1491.23 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1618.35 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1797.58 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1784.05 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1911.72 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1960.66 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1796.87 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1948.75 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1743.71 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1367.32 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1831.94 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1998.53 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1433.38 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1780.50 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1805.50 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 16.95it/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1795.98 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1934.44 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1769.23 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1941.32 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1805.79 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1667.46 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1891.03 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1410.94 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1868.54 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1779.28 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1869.25 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1720.55 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1683.73 examples/s]
# Filter: 100%|██████████| 19/19 [00:00<00:00, 2504.14 examples/s]
# Filter: 100%|██████████| 19/19 [00:00<00:00, 2503.43 examples/s]
# Filter: 100%|██████████| 19/19 [00:00<00:00, 2528.77 examples/s]
# Filter: 100%|██████████| 19/19 [00:00<00:00, 2413.37 examples/s]
# Filter: 100%|██████████| 19/19 [00:00<00:00, 2647.22 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2591.71 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2176.40 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2475.98 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2286.74 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1999.13 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2387.54 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2085.34 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2247.75 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2086.20 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2074.11 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1883.45 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1975.85 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2100.23 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1947.09 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2081.91 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1966.32 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2121.09 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2073.46 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2076.53 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2091.25 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1832.60 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1948.83 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 11.90it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1810.12 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1991.46 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1948.64 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2031.28 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2114.90 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2147.46 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1955.97 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1969.22 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1861.12 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1941.23 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1998.51 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1969.35 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1786.17 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2177.89 examples/s]
#   4%|▍         | 22/522 [00:14<07:33,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 13.63it/s]
#   4%|▍         | 23/522 [00:15<06:06,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00,  9.97it/s]
#   5%|▍         | 24/522 [00:16<06:50,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.00it/s]
#   5%|▍         | 25/522 [00:16<05:48,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.12it/s]
#   5%|▍         | 26/522 [00:17<05:04,  1.63it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 12.65it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 133766.90 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 17.01it/s]
#   5%|▌         | 28/522 [00:18<05:13,  1.58it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.29it/s]
#   6%|▌         | 29/522 [00:18<04:15,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 11.88it/s]
#   6%|▌         | 30/522 [00:19<04:49,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00,  9.73it/s]
#   6%|▌         | 31/522 [00:19<04:24,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00,  9.65it/s]
#   6%|▌         | 32/522 [00:20<04:06,  1.99it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.22it/s]
#   6%|▋         | 33/522 [00:20<03:50,  2.12it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.09it/s]
#   7%|▋         | 34/522 [00:21<03:40,  2.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 10.03it/s]
#   7%|▋         | 35/522 [00:22<05:11,  1.57it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 14.04it/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2114.60 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2254.32 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1850.80 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1938.03 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2083.02 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1951.12 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1458.30 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1674.43 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1568.60 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1283.33 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1434.49 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 220049.89 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1246.41 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1428.72 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1423.00 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1090.28 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1383.71 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1415.99 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1427.90 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1353.44 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 16.74it/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1465.05 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1514.41 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1430.09 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1463.78 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1466.85 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1459.65 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1362.67 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1521.33 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1471.53 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1526.20 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 220870.44 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 17.12it/s]
#   7%|▋         | 38/522 [00:23<04:58,  1.62it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 17.03it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 218309.56 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 11.12it/s]
#   8%|▊         | 40/522 [00:25<06:03,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.07it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1619.29 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1671.09 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1691.35 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1909.84 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1856.96 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 2072.44 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1942.15 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1770.43 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1438.17 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 175074.75 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1455.60 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1516.61 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1690.06 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1728.13 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1588.30 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1875.04 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1888.26 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1516.93 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1764.17 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1846.42 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 10.63it/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1296.14 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1496.01 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1417.19 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1793.78 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1594.49 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1678.17 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1593.43 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1512.96 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1902.18 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1759.60 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1650.11 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1751.88 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 147301.99 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00,  9.97it/s]
#   8%|▊         | 43/522 [00:27<06:12,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 13.50it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1802.62 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1915.02 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1905.44 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1799.71 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1545.01 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1616.67 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1474.53 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1322.21 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1226.01 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1410.28 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1155.36 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1288.41 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1478.64 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1409.28 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1429.02 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1343.98 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 16.71it/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1364.53 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1413.46 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1464.85 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1532.05 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1447.31 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1463.52 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1337.85 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1230.43 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1448.86 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1441.34 examples/s]
#   9%|▊         | 45/522 [00:28<05:25,  1.47it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 16.97it/s]
#   9%|▉         | 46/522 [00:29<04:54,  1.61it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 11.77it/s]
#   9%|▉         | 47/522 [00:29<04:16,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.18it/s]
#   9%|▉         | 48/522 [00:30<03:56,  2.00it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 10.00it/s]
#   9%|▉         | 49/522 [00:31<05:36,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.22it/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1139.80 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1150.19 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1002.97 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1033.08 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1096.55 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1107.55 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1131.04 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1146.10 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 16.87it/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1088.97 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1179.17 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1125.31 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1206.82 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1173.07 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1161.17 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1213.85 examples/s]
# Filter: 100%|██████████| 8/8 [00:00<00:00, 1116.21 examples/s]
#  10%|▉         | 51/522 [00:32<04:26,  1.77it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 12.11it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 134068.77 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 15.39it/s]
#  10%|█         | 53/522 [00:33<04:11,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 12.78it/s]
#  10%|█         | 54/522 [00:33<04:10,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 14.97it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 212625.64 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.32it/s]
#  11%|█         | 56/522 [00:34<03:33,  2.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 14.73it/s]
#  11%|█         | 57/522 [00:35<03:42,  2.09it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 16.65it/s]
#  11%|█         | 58/522 [00:35<03:11,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 4/4 [00:00<00:00, 14.23it/s]
#  11%|█▏        | 59/522 [00:35<03:25,  2.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.15it/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1521.58 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1518.66 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1549.43 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1449.99 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 163813.03 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1307.12 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1291.68 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1479.71 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1268.62 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1391.19 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1365.05 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1400.22 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1625.81 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1636.89 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1537.09 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 10.70it/s]
# ...
#  96%|█████████▋| 503/522 [05:06<00:10,  1.76it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.04it/s]
#  97%|█████████▋| 504/522 [05:07<00:09,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.03it/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 212739.28 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.31it/s]
#  97%|█████████▋| 506/522 [05:07<00:06,  2.56it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 11.00it/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 1620.60 examples/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 1967.92 examples/s]
# Filter: 100%|██████████| 18/18 [00:00<00:00, 2241.21 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2469.97 examples/s]
# Filter: 100%|██████████| 17/17 [00:00<00:00, 2585.88 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2202.10 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1880.22 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 1696.60 examples/s]
# Filter: 100%|██████████| 16/16 [00:00<00:00, 2289.47 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2221.40 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2040.56 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 2119.83 examples/s]
# Filter: 100%|██████████| 15/15 [00:00<00:00, 1705.09 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1932.41 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1772.69 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2098.13 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1904.83 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1919.15 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1993.22 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2043.37 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2086.94 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1823.55 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2056.61 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2039.75 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1886.35 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2037.20 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1942.71 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 7/7 [00:00<00:00, 10.41it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1582.80 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1632.43 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1667.38 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1899.66 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2031.21 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1754.52 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2113.68 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2008.63 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2171.85 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2132.96 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1628.68 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2129.78 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1886.17 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1948.64 examples/s]
#  97%|█████████▋| 508/522 [05:09<00:11,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 10.18it/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1480.32 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1582.71 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1278.30 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1340.64 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1570.85 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1584.39 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1716.42 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1631.97 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1628.74 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1618.51 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1696.85 examples/s]
# Filter: 100%|██████████| 11/11 [00:00<00:00, 1672.19 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1467.93 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1480.73 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1449.26 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1373.88 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1481.88 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1460.97 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1313.55 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1444.77 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1457.72 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1408.24 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 10.03it/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1167.16 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1051.70 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1257.29 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1232.39 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1562.07 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1549.66 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1420.16 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1501.45 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1442.73 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1476.40 examples/s]
# Filter: 100%|██████████| 4745/4745 [00:00<00:00, 149024.86 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00,  9.90it/s]
#  98%|█████████▊| 511/522 [05:11<00:07,  1.46it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00,  8.51it/s]
#  98%|█████████▊| 512/522 [05:12<00:06,  1.62it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 13.57it/s]
#  98%|█████████▊| 513/522 [05:12<00:04,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 17.10it/s]
#  98%|█████████▊| 514/522 [05:12<00:03,  2.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 16.83it/s]
#  99%|█████████▊| 515/522 [05:13<00:02,  2.59it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 10.04it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1420.94 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1619.60 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1679.64 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2184.70 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2095.06 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 2107.77 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1843.40 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1915.21 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1867.32 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1806.59 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1467.91 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1857.67 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1840.95 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1556.09 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1568.11 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1526.45 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1691.02 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1716.98 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1782.09 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1873.22 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 6/6 [00:00<00:00, 16.22it/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1755.55 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1833.17 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1824.01 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1787.73 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1629.44 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1860.62 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1861.03 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1704.02 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1670.59 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1561.06 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1680.75 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1750.79 examples/s]
#  99%|█████████▉| 517/522 [05:14<00:03,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 11.60it/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1544.50 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1417.58 examples/s]
# Filter: 100%|██████████| 14/14 [00:00<00:00, 1728.39 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1725.61 examples/s]
# Filter: 100%|██████████| 13/13 [00:00<00:00, 1535.60 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1533.10 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1650.81 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1579.92 examples/s]
# Filter: 100%|██████████| 12/12 [00:00<00:00, 1595.80 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1418.19 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1451.92 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1472.05 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1446.01 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1357.82 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1549.54 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1186.34 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1448.26 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1501.29 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1355.58 examples/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 10.15it/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1185.33 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1331.02 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1126.80 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1498.07 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1651.95 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1593.52 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1424.94 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1552.76 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1360.95 examples/s]
# Filter: 100%|██████████| 10/10 [00:00<00:00, 1513.59 examples/s]
#  99%|█████████▉| 519/522 [05:16<00:02,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 3/3 [00:00<00:00, 16.23it/s]
# 100%|█████████▉| 520/522 [05:16<00:01,  1.71it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 16.99it/s]
# 100%|█████████▉| 521/522 [05:17<00:00,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 5/5 [00:00<00:00, 14.93it/s]
# 100%|██████████| 522/522 [05:17<00:00,  1.64it/s]

# %%
processed_dataset.save_to_disk("auto_ravel/Q5_processed")
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 35208/35208 [00:00<00:00, 385421.41 examples/s]
